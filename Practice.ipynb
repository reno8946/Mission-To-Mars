# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
# Path to chromedriver
# !which chromedriver
# Out:
# which: no chromedriver in (/c/Users/16307/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/16307/bin:/c/Windows/system32:/c/Windows:/c/Windows/System32/Wbem:/c/Windows/System32/WindowsPowerShell/v1.0:/c/Windows/System32/OpenSSH:/cmd:/c/Program Files/Git LFS:/c/Users/16307/anaconda:/c/Users/16307/anaconda/Library/mingw-w64/bin:/c/Users/16307/anaconda/Library/usr/bin:/c/Users/16307/anaconda/Library/bin:/c/Users/16307/anaconda/Scripts:/c/Users/16307/AppData/Local/Programs/Python/Python37/Scripts:/c/Users/16307/AppData/Local/Programs/Python/Python37:/c/Users/16307/AppData/Local/Microsoft/WindowsApps:/c/Users/16307/AppData/Local/Programs/Microsoft VS Code/bin:/c/Program Files/MongoDB/Server/4.4/bin:/usr/bin/vendor_perl:/usr/bin/core_perl)

# %%
# Windows users
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit the Quotes to Scrape site
url = 'http://quotes.toscrape.com/'
browser.visit(url)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-efd25ec2021e> in <module>
#       1 # Visit the Quotes to Scrape site
#       2 url = 'http://quotes.toscrape.com/'
# ----> 3 browser.visit(url)
#
# ~\anaconda\lib\site-packages\splinter\driver\webdriver\__init__.py in visit(self, url)
#     285
#     286     def visit(self, url):
# --> 287         self.driver.get(url)
#     288
#     289     def back(self):
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.111)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-217c4157b965> in <module>
#       1 # Parse the HTML
# ----> 2 html = browser.html
#       3 html_soup = soup(html, 'html.parser')
#
# ~\anaconda\lib\site-packages\splinter\driver\webdriver\__init__.py in html(self)
#     274     @property
#     275     def html(self):
# --> 276         return self.driver.page_source
#     277
#     278     @property
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.111)

# %%
# Scrape the Title
title = html_soup.find('h2').text
title

# %%
# Scrape the top ten tags
tag_box = html_soup.find('div', class_='tags-box')
# tag_box
tags = tag_box.find_all('a', class_='tag')

for tag in tags:
    word = tag.text
    print(word)

# %%
url = 'http://quotes.toscrape.com/'
browser.visit(url)

# %%
for x in range(1, 6):
   html = browser.html
   quote_soup = soup (html, 'html.parser')
   quotes = quote_soup.find_all('span', class_='text')
   for quote in quotes:
      print('page:', x, '----------')
      print(quote.text)
   browser.links.find_by_partial_text('Next')
